# %%
import os
import numpy as np
import torch
from PIL import Image

# %%
class PENNFUDAN(object):
    def __init__(self, root, transforms):
        self.root = root
        self.transforms = transforms
        #print("Images path ", os.listdir(os.path.join(root, "PNGImages")))
        self.imgs = list(sorted(os.listdir(os.path.join(root, "PNGImages"))))
        self.masks = list(sorted(os.listdir(os.path.join(root, "PedMasks"))))
        
    def __getitem__(self, idx):
        img_path = os.path.join(self.root, 'PNGImages', self.imgs[idx])
        mask_path = os.path.join(self.root, 'PedMasks', self.masks[idx])
        
        img = Image.open(img_path).convert("RGB")
        mask = Image.open(mask_path)
        mask = np.array(mask)
        #print(mask.shape)
        
        obj_ids = np.unique(mask)
        obj_ids = obj_ids[1:]
        #print(obj_ids.shape)
        
        masks = mask == obj_ids[:, None, None]
        num_objs = len(obj_ids)
        boxes = []
        for i in range(num_objs):
            pos = np.where(masks[i])
            xmin = np.min(pos[1])
            xmax = np.max(pos[1])
            ymin = np.min(pos[0])
            ymax = np.max(pos[0])
            boxes.append([xmin, ymin, xmax, ymax])
            
        boxes = torch.as_tensor(boxes, dtype=torch.float32)
        labels = torch.ones((num_objs, ), dtype=torch.int64)
        masks = torch.as_tensor(masks, dtype=torch.uint8)
        
        image_id = torch.tensor([idx])
        area = (boxes[:, 3] - boxes[:, 1] * (boxes[:, 2] - boxes[:, 0] ))
        iscrowd = torch.zeros((num_objs,), dtype=torch.int64)
        
        target = {}
        target["boxes"] = boxes
        target["labels"] = labels
        target["masks"] = masks
        target["image_id"] = image_id
        target["area"] = area
        target["iscrowd"] = iscrowd
        
        if self.transforms is not None:
            img, target = self.transforms(img, target)
            
        return img, target
    
    def __len__(self):
        return len(self.imgs)

# %% [markdown]
# ### 1 - Finetuning from a pretrained model

# %%
import torchvision
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor

model = torchvision.models.detection.fasterrcnn_resnet50_fpn(pretrained=True)
num_classes = 2
#print(model.roi_heads)

# %%
in_feature = model.roi_heads.box_predictor.cls_score.in_features
model.roi_heads.box_predictors = FastRCNNPredictor(in_feature, num_classes)

# %% [markdown]
# ### 2 - Modifying the model to add a different backbone
#
# Ripping Down the Faster RCNN model with Mobilenet !

# %%
from torchvision.models.detection import FasterRCNN
from torchvision.models.detection.rpn import AnchorGenerator

# %%
backbone = torchvision.models.mobilenet_v2(pretrained=True).features

# %%
backbone.out_channels =1280

# %%
anchor_generator = AnchorGenerator(sizes=((32, 64, 128, 256, 512),),
                                 aspect_ratios=((0.5, 1.0, 2.0),))

# %%
roi_pooler = torchvision.ops.MultiScaleRoIAlign(featmap_names=[0],
                                               output_size=7,
                                               sampling_ratio=2)
fasterrcnn_model = FasterRCNN(backbone,
                  num_classes=2,
                  rpn_anchor_generator=anchor_generator,
                  box_roi_pool=roi_pooler)

# %% [markdown]
# ### PENNFUDAN Dataset

# %%
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor
from torchvision.models.detection.mask_rcnn import MaskRCNNPredictor

# %%
def get_model_instance_segmentation(num_classes):
    
    model = torchvision.models.detection.maskrcnn_resnet50_fpn(pretrained=True)
    
    in_features = model.roi_heads.box_predictor.cls_score.in_features
    print("get_model_instance_segmentation - in_features: ",in_features)
    model.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes)
    
    in_features_mask = model.roi_heads.mask_predictor.conv5_mask.in_channels
    print(in_features_mask)
    hidden_layer = 256
    
    model.roi_heads.mask_predictor = MaskRCNNPredictor(in_features_mask,
                                                      hidden_layer,
                                                      num_classes)
    
    return model

# %%
import transforms as T
import utils
def get_transform(train):
    transforms = []
    transforms.append(T.ToTensor())
    if train:
        transforms.append(T.RandomHorizontalFlip(0.5))
    
    return T.Compose(transforms)

# %%
from engine import train_one_epoch, evaluate
import utils

# %%
def main():
    device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
    print(device)
    num_classes = 2
    
    dataset = PENNFUDAN('PennFudanPed', get_transform(train=True))
    dataset_test = PENNFUDAN('PennFudanPed', get_transform(train=False))
    
    indices = torch.randperm(len(dataset)).tolist()
    dataset = torch.utils.data.Subset(dataset, indices[:-50])
    dataset_test = torch.utils.data.Subset(dataset_test, indices[-50:])
    
    data_loader = torch.utils.data.DataLoader(dataset, batch_size=2,
                                             shuffle=True, num_workers=4,
                                             collate_fn=utils.collate_fn)
    data_loader_test = torch.utils.data.DataLoader(dataset_test, batch_size=1,
                                             shuffle=False, num_workers=4,
                                             collate_fn=utils.collate_fn)
    
    model = get_model_instance_segmentation(num_classes)
    model.to(device)
    
    params = [p for p in model.parameters() if p.requires_grad]
    optimizer = torch.optim.SGD(params, lr=0.005,
                               momentum=0.9, weight_decay=0.0005)
    
    lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer,
                                                  step_size=3,
                                                  gamma=0.1)
    num_epochs = 10
    for epoch in range(num_epochs):
        train_one_epoch(model, optimizer, data_loader, device, epoch, print_freq=10)
        lr_scheduler.step()
        evaluate(model, data_loader_test, device=device)
        
    return ("That's it !")

# %%
main()
# Out:
# cuda
# get_model_instance_segmentation - in_features:  1024
# 256
# /opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:2854: UserWarning: The default behavior for interpolate/upsample with float scale_factor will change in 1.6.0 to align with other frameworks/libraries, and use scale_factor directly, instead of relying on the computed output size. If you wish to keep the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor will change "
# /pytorch/torch/csrc/utils/python_arg_parser.cpp:756: UserWarning: This overload of nonzero is deprecated:
# 	nonzero(Tensor input, *, Tensor out)
# Consider using one of the following signatures instead:
# 	nonzero(Tensor input, *, bool as_tuple)
# Epoch: [0]  [ 0/60]  eta: 0:00:34  lr: 0.000090  loss: 2.9290 (2.9290)  loss_classifier: 0.8120 (0.8120)  loss_box_reg: 0.2290 (0.2290)  loss_mask: 1.8441 (1.8441)  loss_objectness: 0.0335 (0.0335)  loss_rpn_box_reg: 0.0104 (0.0104)  time: 0.5746  data: 0.1427  max mem: 2550
# Epoch: [0]  [10/60]  eta: 0:00:18  lr: 0.000936  loss: 1.3332 (1.7261)  loss_classifier: 0.4867 (0.5150)  loss_box_reg: 0.1805 (0.1890)  loss_mask: 0.7630 (0.9858)  loss_objectness: 0.0245 (0.0280)  loss_rpn_box_reg: 0.0091 (0.0083)  time: 0.3601  data: 0.0181  max mem: 2861
# Epoch: [0]  [20/60]  eta: 0:00:14  lr: 0.001783  loss: 0.9235 (1.2428)  loss_classifier: 0.2774 (0.3740)  loss_box_reg: 0.1712 (0.1804)  loss_mask: 0.3625 (0.6543)  loss_objectness: 0.0168 (0.0230)  loss_rpn_box_reg: 0.0100 (0.0112)  time: 0.3453  data: 0.0045  max mem: 3065
# Epoch: [0]  [30/60]  eta: 0:00:10  lr: 0.002629  loss: 0.4942 (1.0005)  loss_classifier: 0.1020 (0.2842)  loss_box_reg: 0.1578 (0.1755)  loss_mask: 0.2282 (0.5106)  loss_objectness: 0.0073 (0.0185)  loss_rpn_box_reg: 0.0115 (0.0117)  time: 0.3469  data: 0.0033  max mem: 3065
# Epoch: [0]  [40/60]  eta: 0:00:06  lr: 0.003476  loss: 0.4165 (0.8371)  loss_classifier: 0.0622 (0.2258)  loss_box_reg: 0.1257 (0.1573)  loss_mask: 0.1821 (0.4283)  loss_objectness: 0.0034 (0.0149)  loss_rpn_box_reg: 0.0102 (0.0109)  time: 0.3331  data: 0.0033  max mem: 3065
# Epoch: [0]  [50/60]  eta: 0:00:03  lr: 0.004323  loss: 0.3148 (0.7404)  loss_classifier: 0.0423 (0.1916)  loss_box_reg: 0.0698 (0.1411)  loss_mask: 0.1821 (0.3835)  loss_objectness: 0.0018 (0.0129)  loss_rpn_box_reg: 0.0087 (0.0113)  time: 0.3434  data: 0.0034  max mem: 3065
# Epoch: [0]  [59/60]  eta: 0:00:00  lr: 0.005000  loss: 0.2938 (0.6689)  loss_classifier: 0.0403 (0.1684)  loss_box_reg: 0.0621 (0.1274)  loss_mask: 0.1762 (0.3500)  loss_objectness: 0.0018 (0.0112)  loss_rpn_box_reg: 0.0109 (0.0119)  time: 0.3574  data: 0.0034  max mem: 3065
# Epoch: [0] Total time: 0:00:20 (0.3500 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:09  model_time: 0.0779 (0.0779)  evaluator_time: 0.0025 (0.0025)  time: 0.1811  data: 0.0998  max mem: 3065
# Test:  [49/50]  eta: 0:00:00  model_time: 0.0682 (0.0694)  evaluator_time: 0.0031 (0.0052)  time: 0.0782  data: 0.0017  max mem: 3065
# Test: Total time: 0:00:03 (0.0797 s / it)
# Averaged stats: model_time: 0.0682 (0.0694)  evaluator_time: 0.0031 (0.0052)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.038
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.071
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.031
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.800
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.800
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.800
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.800
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.025
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.067
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.400
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.400
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.400
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.400
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
# Epoch: [1]  [ 0/60]  eta: 0:00:34  lr: 0.005000  loss: 0.2632 (0.2632)  loss_classifier: 0.0442 (0.0442)  loss_box_reg: 0.0758 (0.0758)  loss_mask: 0.1211 (0.1211)  loss_objectness: 0.0005 (0.0005)  loss_rpn_box_reg: 0.0217 (0.0217)  time: 0.5668  data: 0.1493  max mem: 3065
# Epoch: [1]  [10/60]  eta: 0:00:18  lr: 0.005000  loss: 0.2626 (0.2473)  loss_classifier: 0.0327 (0.0337)  loss_box_reg: 0.0428 (0.0460)  loss_mask: 0.1404 (0.1519)  loss_objectness: 0.0009 (0.0017)  loss_rpn_box_reg: 0.0128 (0.0139)  time: 0.3774  data: 0.0161  max mem: 3065
# Epoch: [1]  [20/60]  eta: 0:00:14  lr: 0.005000  loss: 0.2219 (0.2323)  loss_classifier: 0.0327 (0.0372)  loss_box_reg: 0.0285 (0.0381)  loss_mask: 0.1383 (0.1423)  loss_objectness: 0.0009 (0.0021)  loss_rpn_box_reg: 0.0117 (0.0127)  time: 0.3433  data: 0.0030  max mem: 3065
# Epoch: [1]  [30/60]  eta: 0:00:10  lr: 0.005000  loss: 0.1999 (0.2231)  loss_classifier: 0.0306 (0.0361)  loss_box_reg: 0.0216 (0.0336)  loss_mask: 0.1264 (0.1389)  loss_objectness: 0.0009 (0.0019)  loss_rpn_box_reg: 0.0100 (0.0126)  time: 0.3323  data: 0.0033  max mem: 3065
# Epoch: [1]  [40/60]  eta: 0:00:06  lr: 0.005000  loss: 0.1951 (0.2256)  loss_classifier: 0.0306 (0.0372)  loss_box_reg: 0.0216 (0.0339)  loss_mask: 0.1300 (0.1401)  loss_objectness: 0.0009 (0.0017)  loss_rpn_box_reg: 0.0115 (0.0128)  time: 0.3411  data: 0.0034  max mem: 3065
# Epoch: [1]  [50/60]  eta: 0:00:03  lr: 0.005000  loss: 0.2163 (0.2229)  loss_classifier: 0.0297 (0.0358)  loss_box_reg: 0.0213 (0.0314)  loss_mask: 0.1334 (0.1418)  loss_objectness: 0.0008 (0.0016)  loss_rpn_box_reg: 0.0101 (0.0122)  time: 0.3495  data: 0.0034  max mem: 3341
# Epoch: [1]  [59/60]  eta: 0:00:00  lr: 0.005000  loss: 0.2252 (0.2278)  loss_classifier: 0.0363 (0.0373)  loss_box_reg: 0.0229 (0.0307)  loss_mask: 0.1381 (0.1457)  loss_objectness: 0.0010 (0.0018)  loss_rpn_box_reg: 0.0101 (0.0123)  time: 0.3432  data: 0.0033  max mem: 3341
# Epoch: [1] Total time: 0:00:20 (0.3470 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:09  model_time: 0.0748 (0.0748)  evaluator_time: 0.0044 (0.0044)  time: 0.1821  data: 0.1019  max mem: 3341
# Test:  [49/50]  eta: 0:00:00  model_time: 0.0739 (0.0767)  evaluator_time: 0.0036 (0.0046)  time: 0.0826  data: 0.0018  max mem: 3341
# Test: Total time: 0:00:04 (0.0868 s / it)
# Averaged stats: model_time: 0.0739 (0.0767)  evaluator_time: 0.0036 (0.0046)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.038
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.062
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.048
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.350
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.700
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.700
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.700
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.024
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.062
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.200
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.400
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.400
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.400
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
# Epoch: [2]  [ 0/60]  eta: 0:00:36  lr: 0.005000  loss: 0.2890 (0.2890)  loss_classifier: 0.0292 (0.0292)  loss_box_reg: 0.0331 (0.0331)  loss_mask: 0.2035 (0.2035)  loss_objectness: 0.0010 (0.0010)  loss_rpn_box_reg: 0.0223 (0.0223)  time: 0.6006  data: 0.1739  max mem: 3341
# Epoch: [2]  [10/60]  eta: 0:00:18  lr: 0.005000  loss: 0.1898 (0.1901)  loss_classifier: 0.0292 (0.0295)  loss_box_reg: 0.0129 (0.0140)  loss_mask: 0.1325 (0.1359)  loss_objectness: 0.0010 (0.0014)  loss_rpn_box_reg: 0.0097 (0.0094)  time: 0.3685  data: 0.0180  max mem: 3341
# Epoch: [2]  [20/60]  eta: 0:00:14  lr: 0.005000  loss: 0.1898 (0.2040)  loss_classifier: 0.0300 (0.0322)  loss_box_reg: 0.0129 (0.0189)  loss_mask: 0.1318 (0.1389)  loss_objectness: 0.0008 (0.0017)  loss_rpn_box_reg: 0.0097 (0.0122)  time: 0.3604  data: 0.0028  max mem: 3341
# Epoch: [2]  [30/60]  eta: 0:00:10  lr: 0.005000  loss: 0.2049 (0.2003)  loss_classifier: 0.0305 (0.0308)  loss_box_reg: 0.0136 (0.0189)  loss_mask: 0.1272 (0.1379)  loss_objectness: 0.0008 (0.0016)  loss_rpn_box_reg: 0.0093 (0.0111)  time: 0.3637  data: 0.0033  max mem: 3341
# Epoch: [2]  [40/60]  eta: 0:00:07  lr: 0.005000  loss: 0.1716 (0.1938)  loss_classifier: 0.0243 (0.0309)  loss_box_reg: 0.0136 (0.0183)  loss_mask: 0.1115 (0.1322)  loss_objectness: 0.0008 (0.0015)  loss_rpn_box_reg: 0.0082 (0.0109)  time: 0.3644  data: 0.0034  max mem: 3341
# Epoch: [2]  [50/60]  eta: 0:00:03  lr: 0.005000  loss: 0.1778 (0.1944)  loss_classifier: 0.0307 (0.0311)  loss_box_reg: 0.0148 (0.0190)  loss_mask: 0.1167 (0.1321)  loss_objectness: 0.0008 (0.0014)  loss_rpn_box_reg: 0.0092 (0.0108)  time: 0.3706  data: 0.0034  max mem: 3341
# Epoch: [2]  [59/60]  eta: 0:00:00  lr: 0.005000  loss: 0.1689 (0.1916)  loss_classifier: 0.0240 (0.0301)  loss_box_reg: 0.0161 (0.0187)  loss_mask: 0.1225 (0.1308)  loss_objectness: 0.0004 (0.0013)  loss_rpn_box_reg: 0.0099 (0.0107)  time: 0.3623  data: 0.0033  max mem: 3341
# Epoch: [2] Total time: 0:00:22 (0.3677 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:08  model_time: 0.0668 (0.0668)  evaluator_time: 0.0020 (0.0020)  time: 0.1652  data: 0.0955  max mem: 3341
# Test:  [49/50]  eta: 0:00:00  model_time: 0.0768 (0.0730)  evaluator_time: 0.0028 (0.0036)  time: 0.0847  data: 0.0020  max mem: 3341
# Test: Total time: 0:00:04 (0.0819 s / it)
# Averaged stats: model_time: 0.0768 (0.0730)  evaluator_time: 0.0028 (0.0036)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.037
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.059
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.043
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.350
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.700
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.700
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.700
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.028
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.059
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.250
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.500
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.500
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.500
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
# Epoch: [3]  [ 0/60]  eta: 0:00:31  lr: 0.000500  loss: 0.1266 (0.1266)  loss_classifier: 0.0171 (0.0171)  loss_box_reg: 0.0064 (0.0064)  loss_mask: 0.0971 (0.0971)  loss_objectness: 0.0004 (0.0004)  loss_rpn_box_reg: 0.0056 (0.0056)  time: 0.5215  data: 0.1385  max mem: 3341
# Epoch: [3]  [10/60]  eta: 0:00:19  lr: 0.000500  loss: 0.1601 (0.1694)  loss_classifier: 0.0219 (0.0274)  loss_box_reg: 0.0136 (0.0139)  loss_mask: 0.1177 (0.1193)  loss_objectness: 0.0004 (0.0006)  loss_rpn_box_reg: 0.0080 (0.0082)  time: 0.3840  data: 0.0151  max mem: 3341
# Epoch: [3]  [20/60]  eta: 0:00:15  lr: 0.000500  loss: 0.1601 (0.1676)  loss_classifier: 0.0225 (0.0265)  loss_box_reg: 0.0133 (0.0141)  loss_mask: 0.1148 (0.1185)  loss_objectness: 0.0003 (0.0006)  loss_rpn_box_reg: 0.0072 (0.0080)  time: 0.3740  data: 0.0030  max mem: 3341
# Epoch: [3]  [30/60]  eta: 0:00:11  lr: 0.000500  loss: 0.1494 (0.1608)  loss_classifier: 0.0216 (0.0250)  loss_box_reg: 0.0081 (0.0120)  loss_mask: 0.1106 (0.1160)  loss_objectness: 0.0002 (0.0005)  loss_rpn_box_reg: 0.0070 (0.0073)  time: 0.3665  data: 0.0031  max mem: 3341
# Epoch: [3]  [40/60]  eta: 0:00:07  lr: 0.000500  loss: 0.1494 (0.1660)  loss_classifier: 0.0216 (0.0259)  loss_box_reg: 0.0084 (0.0127)  loss_mask: 0.1116 (0.1185)  loss_objectness: 0.0003 (0.0008)  loss_rpn_box_reg: 0.0078 (0.0081)  time: 0.3762  data: 0.0030  max mem: 3341
# Epoch: [3]  [50/60]  eta: 0:00:03  lr: 0.000500  loss: 0.1626 (0.1661)  loss_classifier: 0.0221 (0.0259)  loss_box_reg: 0.0088 (0.0126)  loss_mask: 0.1080 (0.1185)  loss_objectness: 0.0005 (0.0008)  loss_rpn_box_reg: 0.0102 (0.0084)  time: 0.3742  data: 0.0030  max mem: 3341
# Epoch: [3]  [59/60]  eta: 0:00:00  lr: 0.000500  loss: 0.1352 (0.1633)  loss_classifier: 0.0198 (0.0252)  loss_box_reg: 0.0081 (0.0124)  loss_mask: 0.1052 (0.1167)  loss_objectness: 0.0003 (0.0007)  loss_rpn_box_reg: 0.0053 (0.0083)  time: 0.3466  data: 0.0030  max mem: 3341
# Epoch: [3] Total time: 0:00:22 (0.3694 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:08  model_time: 0.0672 (0.0672)  evaluator_time: 0.0020 (0.0020)  time: 0.1643  data: 0.0941  max mem: 3341
# Test:  [49/50]  eta: 0:00:00  model_time: 0.0670 (0.0681)  evaluator_time: 0.0022 (0.0033)  time: 0.0760  data: 0.0018  max mem: 3341
# Test: Total time: 0:00:03 (0.0773 s / it)
# Averaged stats: model_time: 0.0670 (0.0681)  evaluator_time: 0.0022 (0.0033)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.00s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.042
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.062
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.048
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.400
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.800
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.800
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.800
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.025
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.062
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.200
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.400
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.400
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.400
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
# Epoch: [4]  [ 0/60]  eta: 0:00:26  lr: 0.000500  loss: 0.1615 (0.1615)  loss_classifier: 0.0177 (0.0177)  loss_box_reg: 0.0077 (0.0077)  loss_mask: 0.1300 (0.1300)  loss_objectness: 0.0005 (0.0005)  loss_rpn_box_reg: 0.0056 (0.0056)  time: 0.4379  data: 0.1291  max mem: 3341
# Epoch: [4]  [10/60]  eta: 0:00:19  lr: 0.000500  loss: 0.1695 (0.1795)  loss_classifier: 0.0273 (0.0306)  loss_box_reg: 0.0111 (0.0152)  loss_mask: 0.1269 (0.1228)  loss_objectness: 0.0010 (0.0013)  loss_rpn_box_reg: 0.0097 (0.0096)  time: 0.3944  data: 0.0146  max mem: 3341
# Epoch: [4]  [20/60]  eta: 0:00:15  lr: 0.000500  loss: 0.1486 (0.1645)  loss_classifier: 0.0250 (0.0259)  loss_box_reg: 0.0103 (0.0121)  loss_mask: 0.1029 (0.1175)  loss_objectness: 0.0003 (0.0008)  loss_rpn_box_reg: 0.0066 (0.0082)  time: 0.3790  data: 0.0032  max mem: 3341
# Epoch: [4]  [30/60]  eta: 0:00:10  lr: 0.000500  loss: 0.1276 (0.1571)  loss_classifier: 0.0220 (0.0241)  loss_box_reg: 0.0044 (0.0109)  loss_mask: 0.1014 (0.1141)  loss_objectness: 0.0002 (0.0007)  loss_rpn_box_reg: 0.0037 (0.0072)  time: 0.3495  data: 0.0033  max mem: 3341
# Epoch: [4]  [40/60]  eta: 0:00:07  lr: 0.000500  loss: 0.1469 (0.1620)  loss_classifier: 0.0245 (0.0255)  loss_box_reg: 0.0088 (0.0120)  loss_mask: 0.1042 (0.1161)  loss_objectness: 0.0004 (0.0009)  loss_rpn_box_reg: 0.0054 (0.0076)  time: 0.3597  data: 0.0035  max mem: 3341
# Epoch: [4]  [50/60]  eta: 0:00:03  lr: 0.000500  loss: 0.1656 (0.1618)  loss_classifier: 0.0273 (0.0260)  loss_box_reg: 0.0126 (0.0118)  loss_mask: 0.1159 (0.1156)  loss_objectness: 0.0004 (0.0008)  loss_rpn_box_reg: 0.0074 (0.0077)  time: 0.3906  data: 0.0034  max mem: 3341
# Epoch: [4]  [59/60]  eta: 0:00:00  lr: 0.000500  loss: 0.1572 (0.1606)  loss_classifier: 0.0241 (0.0256)  loss_box_reg: 0.0092 (0.0115)  loss_mask: 0.1062 (0.1150)  loss_objectness: 0.0004 (0.0008)  loss_rpn_box_reg: 0.0074 (0.0078)  time: 0.3798  data: 0.0033  max mem: 3341
# Epoch: [4] Total time: 0:00:22 (0.3755 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:08  model_time: 0.0667 (0.0667)  evaluator_time: 0.0020 (0.0020)  time: 0.1646  data: 0.0948  max mem: 3341
# Test:  [49/50]  eta: 0:00:00  model_time: 0.0671 (0.0682)  evaluator_time: 0.0022 (0.0031)  time: 0.0761  data: 0.0018  max mem: 3341
# Test: Total time: 0:00:03 (0.0763 s / it)
# Averaged stats: model_time: 0.0671 (0.0682)  evaluator_time: 0.0022 (0.0031)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.00s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.037
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.059
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.043
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.350
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.700
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.700
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.700
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.028
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.059
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.250
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.500
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.500
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.500
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
# Epoch: [5]  [ 0/60]  eta: 0:00:32  lr: 0.000500  loss: 0.2273 (0.2273)  loss_classifier: 0.0329 (0.0329)  loss_box_reg: 0.0257 (0.0257)  loss_mask: 0.1558 (0.1558)  loss_objectness: 0.0008 (0.0008)  loss_rpn_box_reg: 0.0121 (0.0121)  time: 0.5359  data: 0.1322  max mem: 3341
# Epoch: [5]  [10/60]  eta: 0:00:17  lr: 0.000500  loss: 0.1342 (0.1661)  loss_classifier: 0.0242 (0.0270)  loss_box_reg: 0.0075 (0.0121)  loss_mask: 0.1132 (0.1189)  loss_objectness: 0.0002 (0.0012)  loss_rpn_box_reg: 0.0055 (0.0068)  time: 0.3598  data: 0.0148  max mem: 3341
# Epoch: [5]  [20/60]  eta: 0:00:14  lr: 0.000500  loss: 0.1502 (0.1654)  loss_classifier: 0.0242 (0.0268)  loss_box_reg: 0.0077 (0.0118)  loss_mask: 0.1116 (0.1190)  loss_objectness: 0.0002 (0.0009)  loss_rpn_box_reg: 0.0055 (0.0068)  time: 0.3644  data: 0.0032  max mem: 3341
# Epoch: [5]  [30/60]  eta: 0:00:11  lr: 0.000500  loss: 0.1560 (0.1662)  loss_classifier: 0.0243 (0.0269)  loss_box_reg: 0.0108 (0.0121)  loss_mask: 0.1165 (0.1183)  loss_objectness: 0.0003 (0.0008)  loss_rpn_box_reg: 0.0076 (0.0081)  time: 0.3901  data: 0.0032  max mem: 3341
# Epoch: [5]  [40/60]  eta: 0:00:07  lr: 0.000500  loss: 0.1404 (0.1607)  loss_classifier: 0.0225 (0.0257)  loss_box_reg: 0.0085 (0.0111)  loss_mask: 0.1084 (0.1155)  loss_objectness: 0.0003 (0.0008)  loss_rpn_box_reg: 0.0067 (0.0076)  time: 0.3705  data: 0.0032  max mem: 3341
# Epoch: [5]  [50/60]  eta: 0:00:03  lr: 0.000500  loss: 0.1403 (0.1578)  loss_classifier: 0.0183 (0.0249)  loss_box_reg: 0.0057 (0.0107)  loss_mask: 0.1048 (0.1141)  loss_objectness: 0.0002 (0.0007)  loss_rpn_box_reg: 0.0065 (0.0075)  time: 0.3710  data: 0.0033  max mem: 3341
# Epoch: [5]  [59/60]  eta: 0:00:00  lr: 0.000500  loss: 0.1438 (0.1607)  loss_classifier: 0.0219 (0.0252)  loss_box_reg: 0.0083 (0.0109)  loss_mask: 0.1083 (0.1163)  loss_objectness: 0.0003 (0.0008)  loss_rpn_box_reg: 0.0067 (0.0076)  time: 0.3756  data: 0.0034  max mem: 3341
# Epoch: [5] Total time: 0:00:22 (0.3739 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:08  model_time: 0.0668 (0.0668)  evaluator_time: 0.0021 (0.0021)  time: 0.1668  data: 0.0969  max mem: 3341
# Test:  [49/50]  eta: 0:00:00  model_time: 0.0681 (0.0689)  evaluator_time: 0.0023 (0.0032)  time: 0.0769  data: 0.0018  max mem: 3341
# Test: Total time: 0:00:03 (0.0774 s / it)
# Averaged stats: model_time: 0.0681 (0.0689)  evaluator_time: 0.0023 (0.0032)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.00s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.037
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.059
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.045
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.350
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.700
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.700
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.700
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.024
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.059
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.200
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.400
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.400
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.400
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
# Epoch: [6]  [ 0/60]  eta: 0:00:29  lr: 0.000050  loss: 0.2120 (0.2120)  loss_classifier: 0.0454 (0.0454)  loss_box_reg: 0.0190 (0.0190)  loss_mask: 0.1333 (0.1333)  loss_objectness: 0.0040 (0.0040)  loss_rpn_box_reg: 0.0104 (0.0104)  time: 0.4867  data: 0.1669  max mem: 3341
# Epoch: [6]  [10/60]  eta: 0:00:18  lr: 0.000050  loss: 0.1386 (0.1559)  loss_classifier: 0.0219 (0.0244)  loss_box_reg: 0.0071 (0.0104)  loss_mask: 0.1104 (0.1133)  loss_objectness: 0.0002 (0.0008)  loss_rpn_box_reg: 0.0072 (0.0069)  time: 0.3796  data: 0.0172  max mem: 3341
# Epoch: [6]  [20/60]  eta: 0:00:15  lr: 0.000050  loss: 0.1343 (0.1552)  loss_classifier: 0.0210 (0.0237)  loss_box_reg: 0.0057 (0.0100)  loss_mask: 0.1104 (0.1139)  loss_objectness: 0.0002 (0.0009)  loss_rpn_box_reg: 0.0052 (0.0068)  time: 0.3719  data: 0.0029  max mem: 3341
# Epoch: [6]  [30/60]  eta: 0:00:11  lr: 0.000050  loss: 0.1535 (0.1572)  loss_classifier: 0.0232 (0.0250)  loss_box_reg: 0.0087 (0.0104)  loss_mask: 0.1138 (0.1137)  loss_objectness: 0.0002 (0.0008)  loss_rpn_box_reg: 0.0067 (0.0073)  time: 0.3789  data: 0.0034  max mem: 3341
# Epoch: [6]  [40/60]  eta: 0:00:07  lr: 0.000050  loss: 0.1569 (0.1588)  loss_classifier: 0.0263 (0.0249)  loss_box_reg: 0.0107 (0.0106)  loss_mask: 0.1049 (0.1151)  loss_objectness: 0.0004 (0.0008)  loss_rpn_box_reg: 0.0068 (0.0075)  time: 0.3739  data: 0.0033  max mem: 3341
# Epoch: [6]  [50/60]  eta: 0:00:03  lr: 0.000050  loss: 0.1596 (0.1601)  loss_classifier: 0.0211 (0.0245)  loss_box_reg: 0.0096 (0.0106)  loss_mask: 0.1095 (0.1165)  loss_objectness: 0.0005 (0.0008)  loss_rpn_box_reg: 0.0056 (0.0077)  time: 0.3630  data: 0.0034  max mem: 3341
# Epoch: [6]  [59/60]  eta: 0:00:00  lr: 0.000050  loss: 0.1437 (0.1581)  loss_classifier: 0.0211 (0.0238)  loss_box_reg: 0.0077 (0.0104)  loss_mask: 0.1080 (0.1158)  loss_objectness: 0.0004 (0.0007)  loss_rpn_box_reg: 0.0054 (0.0074)  time: 0.3554  data: 0.0034  max mem: 3341
# Epoch: [6] Total time: 0:00:22 (0.3685 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:08  model_time: 0.0668 (0.0668)  evaluator_time: 0.0021 (0.0021)  time: 0.1665  data: 0.0965  max mem: 3341
# Test:  [49/50]  eta: 0:00:00  model_time: 0.0675 (0.0690)  evaluator_time: 0.0021 (0.0032)  time: 0.0770  data: 0.0018  max mem: 3341
# Test: Total time: 0:00:03 (0.0773 s / it)
# Averaged stats: model_time: 0.0675 (0.0690)  evaluator_time: 0.0021 (0.0032)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.00s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.037
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.059
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.045
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.350
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.700
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.700
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.700
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.024
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.059
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.200
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.400
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.400
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.400
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
# Epoch: [7]  [ 0/60]  eta: 0:00:30  lr: 0.000050  loss: 0.1421 (0.1421)  loss_classifier: 0.0206 (0.0206)  loss_box_reg: 0.0090 (0.0090)  loss_mask: 0.1052 (0.1052)  loss_objectness: 0.0001 (0.0001)  loss_rpn_box_reg: 0.0073 (0.0073)  time: 0.5019  data: 0.1293  max mem: 3341
# Epoch: [7]  [10/60]  eta: 0:00:17  lr: 0.000050  loss: 0.1727 (0.1723)  loss_classifier: 0.0227 (0.0253)  loss_box_reg: 0.0136 (0.0121)  loss_mask: 0.1175 (0.1252)  loss_objectness: 0.0002 (0.0010)  loss_rpn_box_reg: 0.0073 (0.0087)  time: 0.3585  data: 0.0146  max mem: 3341
# Epoch: [7]  [20/60]  eta: 0:00:14  lr: 0.000050  loss: 0.1397 (0.1645)  loss_classifier: 0.0201 (0.0238)  loss_box_reg: 0.0078 (0.0120)  loss_mask: 0.1043 (0.1197)  loss_objectness: 0.0004 (0.0014)  loss_rpn_box_reg: 0.0057 (0.0076)  time: 0.3471  data: 0.0031  max mem: 3341
# Epoch: [7]  [30/60]  eta: 0:00:10  lr: 0.000050  loss: 0.1394 (0.1574)  loss_classifier: 0.0201 (0.0236)  loss_box_reg: 0.0062 (0.0105)  loss_mask: 0.1027 (0.1147)  loss_objectness: 0.0003 (0.0010)  loss_rpn_box_reg: 0.0061 (0.0076)  time: 0.3657  data: 0.0032  max mem: 3410
# Epoch: [7]  [40/60]  eta: 0:00:07  lr: 0.000050  loss: 0.1380 (0.1542)  loss_classifier: 0.0200 (0.0223)  loss_box_reg: 0.0057 (0.0100)  loss_mask: 0.1049 (0.1137)  loss_objectness: 0.0002 (0.0010)  loss_rpn_box_reg: 0.0065 (0.0072)  time: 0.3691  data: 0.0032  max mem: 3410
# Epoch: [7]  [50/60]  eta: 0:00:03  lr: 0.000050  loss: 0.1633 (0.1591)  loss_classifier: 0.0200 (0.0238)  loss_box_reg: 0.0094 (0.0109)  loss_mask: 0.1086 (0.1157)  loss_objectness: 0.0003 (0.0012)  loss_rpn_box_reg: 0.0061 (0.0075)  time: 0.3622  data: 0.0033  max mem: 3410
# Epoch: [7]  [59/60]  eta: 0:00:00  lr: 0.000050  loss: 0.1680 (0.1576)  loss_classifier: 0.0270 (0.0239)  loss_box_reg: 0.0099 (0.0106)  loss_mask: 0.1082 (0.1147)  loss_objectness: 0.0004 (0.0011)  loss_rpn_box_reg: 0.0050 (0.0072)  time: 0.3673  data: 0.0034  max mem: 3410
# Epoch: [7] Total time: 0:00:21 (0.3635 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:08  model_time: 0.0668 (0.0668)  evaluator_time: 0.0021 (0.0021)  time: 0.1641  data: 0.0941  max mem: 3410
# Test:  [49/50]  eta: 0:00:00  model_time: 0.0763 (0.0733)  evaluator_time: 0.0022 (0.0031)  time: 0.0833  data: 0.0018  max mem: 3410
# Test: Total time: 0:00:04 (0.0815 s / it)
# Averaged stats: model_time: 0.0763 (0.0733)  evaluator_time: 0.0022 (0.0031)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.037
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.059
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.045
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.350
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.700
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.700
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.700
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.024
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.059
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.200
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.400
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.400
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.400
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
# Epoch: [8]  [ 0/60]  eta: 0:00:32  lr: 0.000050  loss: 0.1370 (0.1370)  loss_classifier: 0.0209 (0.0209)  loss_box_reg: 0.0065 (0.0065)  loss_mask: 0.0989 (0.0989)  loss_objectness: 0.0042 (0.0042)  loss_rpn_box_reg: 0.0065 (0.0065)  time: 0.5414  data: 0.1724  max mem: 3410
# Epoch: [8]  [10/60]  eta: 0:00:19  lr: 0.000050  loss: 0.1415 (0.1527)  loss_classifier: 0.0209 (0.0230)  loss_box_reg: 0.0088 (0.0097)  loss_mask: 0.1050 (0.1117)  loss_objectness: 0.0004 (0.0012)  loss_rpn_box_reg: 0.0073 (0.0071)  time: 0.3826  data: 0.0175  max mem: 3410
# Epoch: [8]  [20/60]  eta: 0:00:14  lr: 0.000050  loss: 0.1518 (0.1513)  loss_classifier: 0.0202 (0.0238)  loss_box_reg: 0.0088 (0.0088)  loss_mask: 0.1050 (0.1109)  loss_objectness: 0.0003 (0.0011)  loss_rpn_box_reg: 0.0068 (0.0068)  time: 0.3649  data: 0.0027  max mem: 3410
# Epoch: [8]  [30/60]  eta: 0:00:11  lr: 0.000050  loss: 0.1421 (0.1510)  loss_classifier: 0.0188 (0.0229)  loss_box_reg: 0.0067 (0.0089)  loss_mask: 0.1056 (0.1120)  loss_objectness: 0.0002 (0.0010)  loss_rpn_box_reg: 0.0043 (0.0062)  time: 0.3604  data: 0.0034  max mem: 3410
# Epoch: [8]  [40/60]  eta: 0:00:07  lr: 0.000050  loss: 0.1421 (0.1528)  loss_classifier: 0.0188 (0.0228)  loss_box_reg: 0.0072 (0.0095)  loss_mask: 0.1112 (0.1125)  loss_objectness: 0.0003 (0.0012)  loss_rpn_box_reg: 0.0044 (0.0068)  time: 0.3613  data: 0.0034  max mem: 3410
# Epoch: [8]  [50/60]  eta: 0:00:03  lr: 0.000050  loss: 0.1441 (0.1528)  loss_classifier: 0.0197 (0.0229)  loss_box_reg: 0.0072 (0.0099)  loss_mask: 0.1037 (0.1120)  loss_objectness: 0.0003 (0.0011)  loss_rpn_box_reg: 0.0066 (0.0069)  time: 0.3830  data: 0.0034  max mem: 3410
# Epoch: [8]  [59/60]  eta: 0:00:00  lr: 0.000050  loss: 0.1443 (0.1551)  loss_classifier: 0.0197 (0.0234)  loss_box_reg: 0.0095 (0.0102)  loss_mask: 0.1075 (0.1132)  loss_objectness: 0.0004 (0.0010)  loss_rpn_box_reg: 0.0067 (0.0072)  time: 0.3807  data: 0.0034  max mem: 3410
# Epoch: [8] Total time: 0:00:22 (0.3738 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:08  model_time: 0.0667 (0.0667)  evaluator_time: 0.0021 (0.0021)  time: 0.1704  data: 0.1003  max mem: 3410
# Test:  [49/50]  eta: 0:00:00  model_time: 0.0695 (0.0711)  evaluator_time: 0.0023 (0.0032)  time: 0.0786  data: 0.0018  max mem: 3410
# Test: Total time: 0:00:03 (0.0796 s / it)
# Averaged stats: model_time: 0.0695 (0.0711)  evaluator_time: 0.0023 (0.0032)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.037
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.059
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.045
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.350
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.700
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.700
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.700
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.024
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.059
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.200
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.400
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.400
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.400
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
# Epoch: [9]  [ 0/60]  eta: 0:00:28  lr: 0.000005  loss: 0.1194 (0.1194)  loss_classifier: 0.0118 (0.0118)  loss_box_reg: 0.0038 (0.0038)  loss_mask: 0.0976 (0.0976)  loss_objectness: 0.0002 (0.0002)  loss_rpn_box_reg: 0.0059 (0.0059)  time: 0.4742  data: 0.1353  max mem: 3410
# Epoch: [9]  [10/60]  eta: 0:00:19  lr: 0.000005  loss: 0.1344 (0.1494)  loss_classifier: 0.0179 (0.0193)  loss_box_reg: 0.0059 (0.0079)  loss_mask: 0.1043 (0.1148)  loss_objectness: 0.0003 (0.0004)  loss_rpn_box_reg: 0.0055 (0.0071)  time: 0.3948  data: 0.0153  max mem: 3410
# Epoch: [9]  [20/60]  eta: 0:00:15  lr: 0.000005  loss: 0.1352 (0.1500)  loss_classifier: 0.0197 (0.0223)  loss_box_reg: 0.0086 (0.0087)  loss_mask: 0.1045 (0.1116)  loss_objectness: 0.0002 (0.0006)  loss_rpn_box_reg: 0.0055 (0.0069)  time: 0.3856  data: 0.0034  max mem: 3410
# Epoch: [9]  [30/60]  eta: 0:00:11  lr: 0.000005  loss: 0.1476 (0.1549)  loss_classifier: 0.0236 (0.0228)  loss_box_reg: 0.0098 (0.0099)  loss_mask: 0.1079 (0.1140)  loss_objectness: 0.0002 (0.0006)  loss_rpn_box_reg: 0.0070 (0.0075)  time: 0.3796  data: 0.0034  max mem: 3410
# Epoch: [9]  [40/60]  eta: 0:00:07  lr: 0.000005  loss: 0.1483 (0.1556)  loss_classifier: 0.0170 (0.0216)  loss_box_reg: 0.0070 (0.0097)  loss_mask: 0.1211 (0.1165)  loss_objectness: 0.0003 (0.0007)  loss_rpn_box_reg: 0.0066 (0.0071)  time: 0.3595  data: 0.0033  max mem: 3410
# Epoch: [9]  [50/60]  eta: 0:00:03  lr: 0.000005  loss: 0.1537 (0.1562)  loss_classifier: 0.0170 (0.0225)  loss_box_reg: 0.0058 (0.0099)  loss_mask: 0.1057 (0.1161)  loss_objectness: 0.0003 (0.0007)  loss_rpn_box_reg: 0.0056 (0.0071)  time: 0.3560  data: 0.0030  max mem: 3410
# Epoch: [9]  [59/60]  eta: 0:00:00  lr: 0.000005  loss: 0.1552 (0.1581)  loss_classifier: 0.0265 (0.0231)  loss_box_reg: 0.0098 (0.0103)  loss_mask: 0.1078 (0.1165)  loss_objectness: 0.0004 (0.0008)  loss_rpn_box_reg: 0.0067 (0.0073)  time: 0.3708  data: 0.0030  max mem: 3410
# Epoch: [9] Total time: 0:00:22 (0.3750 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:08  model_time: 0.0667 (0.0667)  evaluator_time: 0.0021 (0.0021)  time: 0.1675  data: 0.0976  max mem: 3410
# Test:  [49/50]  eta: 0:00:00  model_time: 0.0711 (0.0705)  evaluator_time: 0.0022 (0.0031)  time: 0.0798  data: 0.0018  max mem: 3410
# Test: Total time: 0:00:03 (0.0788 s / it)
# Averaged stats: model_time: 0.0711 (0.0705)  evaluator_time: 0.0022 (0.0031)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.00s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.037
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.059
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.045
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.350
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.700
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.700
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.700
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.024
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.059
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.200
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.400
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.400
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.400
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
# "That's it !"
